# %% [markdown]
# # polynomial regression

# %% [markdown]
# ## import lib

# %%
import numpy as np
from utils import Data
from pathlib import Path

# %%
data = Data()
# Out:
# array([[ 0.00000000e+00,  9.51997774e-02,  1.90399555e-01,
#          2.85599332e-01,  3.80799110e-01,  4.75998887e-01,
#          5.71198664e-01,  6.66398442e-01,  7.61598219e-01,
#          8.56797996e-01,  9.51997774e-01,  1.04719755e+00,
#          1.14239733e+00,  1.23759711e+00,  1.33279688e+00,
#          1.42799666e+00,  1.52319644e+00,  1.61839622e+00,
#          1.71359599e+00,  1.80879577e+00,  1.90399555e+00,
#          1.99919533e+00,  2.09439510e+00,  2.18959488e+00,
#          2.28479466e+00,  2.37999443e+00,  2.47519421e+00,
#          2.57039399e+00,  2.66559377e+00,  2.76079354e+00,
#          2.85599332e+00,  2.95119310e+00,  3.04639288e+00,
#          3.14159265e+00,  3.23679243e+00,  3.33199221e+00,
#          3.42719199e+00,  3.52239176e+00,  3.61759154e+00,
#          3.71279132e+00,  3.80799110e+00,  3.90319087e+00,
#          3.99839065e+00,  4.09359043e+00,  4.18879020e+00,
#          4.28398998e+00,  4.37918976e+00,  4.47438954e+00,
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 base = Path(__file__).resolve().parents[1]
#       2 # print(Path(__file__))
#
# NameError: name '__file__' is not defined
