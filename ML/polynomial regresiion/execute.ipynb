# %% [markdown]
# # polynomial regression

# %% [markdown]
# ### import lib

# %%
import numpy as np
import matplotlib.pyplot as plt

from utils import Data
from utils import Plot

# %%
data = Data()
plot = Plot()

# %%
pt = data.get_point()   # (x, y)
x = pt[0]               # x
y = pt[1]               # y

# %% [markdown]
# ### check data

# %%
plot.plot_point(x, y)
